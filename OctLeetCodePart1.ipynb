# %% [markdown]
# <a href="https://colab.research.google.com/github/anhhaibkhn/LeetCode_Daily_Challenges/blob/master/OctLeetCodePart1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
''' 2020 Oct 4th Remove Covered Intervals



'''

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
''' 2020 Oct 5th Complement of Base 10 Integer    

What we actually need to find in this problem is length of our number in bits: if we have 10 = 1010, then complementary is 5 = 101.
Note, that 5 + 10 = 15 = 2^4 - 1. So, let us just find length of our number in bits and subtract N-1.

Complexity time complexity is O(log N) to find its length; space complexity is also O(log N) to keep binary representation of our number.
'''
class Solution:
    def bitwiseComplement(self, N):
        # Ex: 1<<3 = 8. Shift left operation 1 << 3 = 1000 = 8
        return (1<<(len(bin(N)) - 2)) - 1 - N

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
'''2020 Oct 6th Insert into a Binary Search Tree 

Example 3:
Input: root = [4,2,7,1,3,null,null,null,null,null,null], val = 5
Output: [4,2,7,1,3,5]
 
Constraints:

The number of nodes in the tree will be in the range [0, 104].
-108 <= Node.val <= 108
All the values Node.val are unique.
-108 <= val <= 108
It's guaranteed that val does not exist in the original BST.

'''
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def insertIntoBST(self, root: TreeNode, val: int) -> TreeNode:
        if root is None:
            root = TreeNode(val)
            return root
        # tree is not null
        if root.val > val:
            # insert val to the left 
            if root.left is None:
                root.left = TreeNode(val)
            else:
                self.insertIntoBST(root.left, val)
        else:
            # insert val to the right
            if root.right is None:
                root.right = TreeNode(val)
            else:
                self.insertIntoBST(root.right, val)
        
        return root




# fastest submission
class Solution:
    def insertIntoBST(self, root: TreeNode, val: int) -> TreeNode:
        if not root:
            return TreeNode(val)
        
        if root.val < val:
            root.right = self.insertIntoBST(root.right, val)
        else:
            root.left = self.insertIntoBST(root.left, val)
        
        return root

# second fastest submission using iteration
class Solution:
    def insertIntoBST(self, root: TreeNode, val: int) -> TreeNode:
        node = root
        while node:
            if val > node.val:
                if not node.right:
                    node.right = TreeNode(val)
                    return root
                else:
                    node = node.right
            


            else:
                if not node.left:
                    node.left = TreeNode(val)
                    return root
            
                else:
                    node = node.left
        
        return TreeNode(val)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
''' October 14th House robber 2 '''
# https://leetcode.com/problems/house-robber-ii/discuss/299071/Python-O(n)-time-O(1)-space 

class Solution:
    def rob(self, nums: List[int]) -> int:
        def simple_rob(nums, i, j):
            rob, not_rob = 0, 0
            for idx in range(i, j):
                num = nums[idx]
                rob, not_rob = not_rob + num, max(rob, not_rob)
            return max(rob, not_rob)
        
        if not nums:
            return 0
        elif len(nums) == 1:
            return nums[0]
        else:
            n = len(nums)
            return max(simple_rob(nums, 1, n), simple_rob(nums, 0, n-1))
