# %% [markdown]
# <a href="https://colab.research.google.com/github/anhhaibkhn/LeetCode_Daily_Challenges/blob/master/Leetcode_2021_Feb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
""" Trim a Binary Search Tree 

Example 4:
Input: root = [1,null,2], low = 1, high = 3
Output: [1,null,2]

Example 5:
Input: root = [1,null,2], low = 2, high = 4
Output: [2]
 
Constraints:

The number of nodes in the tree in the range [1, 104].
0 <= Node.val <= 104
The value of each node in the tree is unique.
root is guaranteed to be a valid binary search tree.
0 <= low <= high <= 104

""""

class Solution:
    def trimBST(self, root: TreeNode, low: int, high: int) -> TreeNode:
        
        if not root:
            return None
        if root.val < low:
            # trim the node and its left subtree, continue with right subtree
            return self.trimBST(root.right,low, high)
        elif root.val > high:
            #  trim the node and its right subtree, continue with left subtree
            return self.trimBST(root.left,low, high)
        else:
            # keep node.val that within the range
            root.left = self.trimBST(root.left,low, high)
            root.right = self.trimBST(root.right,low, high)
            return root

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# approach 1 Hash table 
class Solution:
    def hasCycle(self, head: ListNode) -> bool:
        nodes_seen = set()
        while head is not None:
            if head in nodes_seen:
                return True
            nodes_seen.add(head)
            head = head.next
        return False


# apporach 2: 2 pointers

# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, x):
#         self.val = x
#         self.next = None

class Solution:
    def hasCycle(self, head: ListNode) -> bool:
        
        if head is None:
            return False
        
        slow = fast = head
        
        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next
            
            if fast and slow.val == fast.val:
                return True       
        
        return False

# 2 pointer start from different head and head.next
class Solution:
    def hasCycle(self, head: ListNode) -> bool:
        
        if head == None:
            return False
        
        slow = head
        fast = head.next
        
        while slow != fast:
            if fast == None or fast.next == None:
                return False 
            
            slow = slow.next
            fast = fast.next.next
        
        return True

# %%
us = set()
s = "00110110"
k = 2
for i in range(len(s) + 1-k) : 
    print(i,s[i:i+k])
    us.add(s[i:i+k])   

print(us)
# Out:
# 0 00
# 1 01
# 2 11
# 3 10
# 4 01
# 5 11
# 6 10
# {'00', '10', '11', '01'}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def swapNodes(self, head: ListNode, k: int) -> ListNode:
        p1, p2, tmp = None, None, head
        
        while tmp:
            k -= 1
            # move p2 until the kth postion from the last
            p2 = p2.next if p2 else None 
            
            if k == 0:
                # initilize 2 pointers
                p1 = tmp
                p2 = head
            
            tmp = tmp.next
        p1.val, p2.val = p2.val, p1.val
        return head
